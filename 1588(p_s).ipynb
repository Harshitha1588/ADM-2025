# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshitha1588/ADM-2025/blob/main/1588(p_s).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/employee_data_250-2.csv')

# %%
plt.figure(figsize=(8, 5))
sns.histplot(df['Salary'], bins=10, kde=True, color='blue')
plt.xlabel("Salary (USD)")
plt.ylabel("Number of Employees")
plt.title("Salary Distribution")
plt.show()

# %%
salary_range = pd.cut(df['Salary'], bins=10).value_counts()
print("Most common salary range:", salary_range.idxmax())
# Out:
# Most common salary range: (66114.296, 75070.46]

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["Experience (Years)"], y=df["Salary"], color="blue", alpha=0.6)
sns.regplot(x=df["Experience (Years)"], y=df["Salary"], scatter=False, color="red")

plt.xlabel("Experience (Years)")
plt.ylabel("Salary (USD)")
plt.title("Experience vs. Salary")
plt.show()

# Calculate correlation between Experience and Salary
correlation = df["Experience (Years)"].corr(df["Salary"])
print(f"Correlation between Experience and Salary: {correlation}")
# Out:
# Correlation between Experience and Salary: -0.0008027873830152189

# %%
plt.figure(figsize=(8, 5))
department_counts = df['Department'].value_counts()
sns.barplot(x=department_counts.index, y=department_counts.values, palette='viridis')
plt.xlabel("Department")
plt.ylabel("Number of Employees")
plt.title("Number of Employees per Department")
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-6-5794798d2da8>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=department_counts.index, y=department_counts.values, palette='viridis')

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Department', hue='Job Satisfaction', data=df, palette='muted')
plt.xlabel("Department")
plt.ylabel("Count of Employees")
plt.title("Job Satisfaction Distribution Across Departments")
plt.legend(title='Job Satisfaction')
plt.xticks(rotation=45)
plt.show()

# %%
if 'Experience' in df.columns:
   # Indent the code block within the 'if' statement
   correlation = df[['Experience', 'Salary']].corr()
   print("Correlation between Experience and Salary:")
   print(correlation)
else:
   print("Skipping correlation analysis: 'Experience' column not found.")
# Out:
# Skipping correlation analysis: 'Experience' column not found.

# %%
print("\n1. Most common salary range:", salary_range.idxmax())
if 'Experience' in df.columns:
    print("2. Correlation between Experience and Salary:", correlation.loc['Experience', 'Salary'])
    print("3. Department with highest number of employees:", department_counts.idxmax())
# Out:
# 1. Most common salary range: (66114.296, 75070.46]
